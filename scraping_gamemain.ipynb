# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
urls = pd.read_csv('urls2020_2023.csv',header=None)
urls.drop([0],inplace=True)
urls
# Out:
#         0                                                  1
# 1       0  www.metacritic.com/game/playstation-4/persona-...
# 2       1  www.metacritic.com/game/playstation-4/the-last...
# 3       2               www.metacritic.com/game/switch/hades
# 4       3          www.metacritic.com/game/pc/half-life-alyx
# 5       4  www.metacritic.com/game/switch/ori-and-the-wil...
# ...   ...                                                ...
# 3079  169          www.metacritic.com/game/pc/blood-bowl-iii
# 3080  170  www.metacritic.com/game/switch/nadir-a-grimdar...
# 3081  171           www.metacritic.com/game/pc/colossal-cave
# 3082  172      www.metacritic.com/game/switch/clive-n-wrench
# 3083  173  www.metacritic.com/game/pc/crime-boss-rockay-city
#
# [3083 rows x 2 columns]

# %%
game_title = []
game_date = []
critic_score = []
user_score = []
game_platform = []
game_genre = []
review_bodys = []
game_pulisher = []

urllinks = urls[1]

import random
import time
from time import sleep


for each_url in urllinks:
    header= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:62.0) Gecko/20100101 Firefox/62.0"}
    wait_seconds = random.uniform(0, 1)
    time.sleep(wait_seconds)
    page=requests.get('http://'+str(each_url),headers=header)
    soup = BeautifulSoup(page.text, 'html.parser')

    containers_title = soup.find('div', class_ = 'product_title')
    containers_sub = soup.find('div', class_ = 'product_data')
    containers_metascore = soup.find('a', class_ = 'metascore_anchor')
    containers_user = soup.find('div', class_ = 'userscore_wrap feature_userscore')
    containers_details = soup.find('li', class_ = 'summary_detail product_genre')

    #Game Title
    try:
        game_title_text = containers_title.select('.hover_none')[0].get_text().strip()
        game_title.append(game_title_text)
    except:
        game_title.append('')

    #Game Platform
    try:            
        game_platform_text = containers_title.select('.platform')[0].get_text().strip()
        game_platform.append(game_platform_text)
    except:
        game_platform.append('')

    #Critic Score
    try:
        critic_score_text = containers_metascore.find('span',itemprop='ratingValue').get_text()
        critic_score.append(critic_score_text)
    except:
        critic_score.append('')

    #User Score
    try:
        user_score_text = containers_user.find('a', class_='metascore_anchor').get_text().strip()
        user_score.append(user_score_text)
    except:
        user_score.append('')

    #Game Genre
    try:
        game_genre_text = containers_details.find_all('span',class_='data')
        game_genre_temp = []
        for game_genre_i in game_genre_text:
            game_genre_temp.append(game_genre_i.get_text())
        game_genre.append('/'.join(game_genre_temp))
    except:
        game_genre.append('')

    #Game Publisher
    try:
        publisher_text = containers_sub.find('span', class_='data').get_text().strip().replace('  ','').replace('\n','').replace('\t','').replace(', ','/')
        game_pulisher.append(publisher_text)
    except:
        game_pulisher.append('')

    #Game Release Date
    containers_date = soup.find('li', class_ = 'summary_detail release_data')
    try:
        date_text = containers_date.find('span', class_='data').get_text().strip()
        game_date.append(date_text)
    except:
        game_date.append('')
    
    print(str(game_title_text)+str(game_platform_text)+str(critic_score_text)+str(user_score_text)+str(game_genre_text)+str(publisher_text)+str(date_text))

print(len(game_title))
print(len(game_date))
print(len(critic_score))
print(len(user_score))
print(len(game_platform))
print(len(game_genre))
print(len(game_pulisher))
# Out:
# Persona 5 RoyalPlayStation 4958.5[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]AtlusMar 31, 2020
# The Last of Us Part IIPlayStation 4935.8[<span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Survival</span>]SCEA/Sony Interactive EntertainmentJun 19, 2020
# HadesSwitch939.0[<span class="data">Role-Playing</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Linear</span>, <span class="data">Roguelike</span>]Supergiant GamesSep 17, 2020
# Half-Life: AlyxPC939.2[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Valve SoftwareMar 23, 2020
# Ori and the Will of the WispsSwitch938.7[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>, <span class="data"></span>, <span class="data">Metroidvania</span>]Microsoft Game Studios/iam8bitSep 17, 2020
# HadesPC938.8[<span class="data">Role-Playing</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Linear</span>, <span class="data">Roguelike</span>]Supergiant GamesSep 17, 2020
# Demon's SoulsPlayStation 5928.0[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Sony Interactive Entertainment/PlayStation StudiosNov 11, 2020
# Dragon Quest XI S: Echoes of an Elusive Age - Definitive EditionXbox One928.5[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]Square EnixDec  4, 2020
# Microsoft Flight SimulatorPC917.2[<span class="data">Simulation</span>, <span class="data">Flight</span>, <span class="data">Civilian</span>]Xbox Game StudiosAug 18, 2020
# Crusader Kings IIIPC918.4[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">General</span>]Paradox InteractiveSep  1, 2020
# F1 2020Xbox One917.3[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]CodemastersJul 10, 2020
# Spelunky 2PC916.8[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]MossmouthSep 29, 2020
# Dragon Quest XI S: Echoes of an Elusive Age - Definitive EditionPlayStation 4918.0[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]Square EnixDec  4, 2020
# Animal Crossing: New HorizonsSwitch905.6[<span class="data">Simulation</span>, <span class="data">Virtual</span>, <span class="data">Virtual Life</span>]NintendoMar 20, 2020
# FactorioPC908.1[<span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Business / Tycoon</span>]Wube Software LTD.Aug 14, 2020
# Ori and the Will of the WispsXbox One908.9[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>, <span class="data"></span>, <span class="data">Metroidvania</span>]Microsoft Game Studios/MicrosoftMar 11, 2020
# Yakuza 0Xbox One908.1[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]SegaSoft/SegaFeb 26, 2020
# Yakuza: Like a DragonXbox One898.5[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]SegaNov 10, 2020
# Xenoblade Chronicles: Definitive EditionSwitch898.8[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]NintendoMay 29, 2020
# There is no game : Wrong dimensionPC898.7[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Point-and-Click</span>]Draw Me A PixelAug  6, 2020
# DreamsPlayStation 4898.7[<span class="data">Miscellaneous</span>, <span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Sandbox</span>]SCEE/SCEA/Sony Interactive EntertainmentFeb 14, 2020
# Tony Hawk's Pro Skater 1 + 2PlayStation 4898.7[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Skate / Skateboard</span>]ActivisionSep  4, 2020
# Devil May Cry 5: Special EditionPlayStation 5898.4[<span class="data">Action Adventure</span>, <span class="data">General</span>]CapcomNov 12, 2020
# A Short HikeSwitch888.5[<span class="data">Adventure</span>, <span class="data">General</span>]Whippoorwill LimitedAug 18, 2020
# Tetris Effect: ConnectedXbox Series X887.8[<span class="data">Puzzle</span>, <span class="data">Stacking</span>]Enhance GamesNov 10, 2020
# Tony Hawk's Pro Skater 1 + 2PC887.3[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Skate / Skateboard</span>]ActivisionSep  4, 2020
# Ori and the Will of the WispsPC888.7[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>, <span class="data"></span>, <span class="data">Metroidvania</span>]Microsoft Game StudiosMar 11, 2020
# DOOM EternalXbox One889.0[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Bethesda SoftworksMar 19, 2020
# Tony Hawk's Pro Skater 1 + 2Xbox One887.8[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Skate / Skateboard</span>]Activision/Vicarious VisionsSep  4, 2020
# Halo: The Master Chief Collection - Halo 3PC888.0[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Xbox Game StudiosJul 14, 2020
# F1 2020PC887.2[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]CodemastersJul  9, 2020
# DOOM EternalPC888.8[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Bethesda SoftworksMar 20, 2020
# Pistol WhipPlayStation 4887.1[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Light Gun</span>]Cloudhead GamesJul 30, 2020
# Mortal Kombat 11 UltimatePlayStation 5887.3[<span class="data">Action</span>, <span class="data">Fighting</span>, <span class="data">2D</span>]Warner Bros. Interactive Entertainment/Warner Bros. GamesNov 17, 2020
# Kentucky Route Zero: TV EditionPlayStation 4886.1[<span class="data">Adventure</span>, <span class="data">General</span>]Annapurna InteractiveJan 28, 2020
# Final Fantasy VII RemakePlayStation 4878.1[<span class="data">Japanese-Style</span>, <span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Square EnixApr 10, 2020
# Legends of RuneterraPC876.7[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Card Battle</span>]Riot GamesApr 29, 2020
# Kentucky Route Zero: TV EditionSwitch877.2[<span class="data">Adventure</span>, <span class="data">General</span>]Annapurna InteractiveJan 28, 2020
# Super Mega Baseball 3Switch878.0[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Baseball</span>, <span class="data">Arcade</span>]Metalhead SoftwareMay 13, 2020
# DOOM EternalPlayStation 4878.9[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Bethesda SoftworksMar 20, 2020
# GrindstoneSwitch877.4[<span class="data">Puzzle</span>, <span class="data">General</span>, <span class="data">Matching</span>]Capy GamesDec 15, 2020
# HuntdownXbox One875.7[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Coffee Stain StudiosMay 12, 2020
# Monster Hunter: World - IcebornePC877.8[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]CapcomJan  9, 2020
# Persona 4 GoldenPC878.9[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]Sega/AtlusJun 13, 2020
# Streets of Rage 4Switch878.3[<span class="data">General</span>, <span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">2D</span>]DotEmuApr 30, 2020
# Spelunky 2PlayStation 4877.8[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]MossmouthSep 15, 2020
# F1 2020PlayStation 4867.8[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]CodemastersJul  6, 2020
# Death StrandingPC867.8[<span class="data">Action</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Open-World</span>]505 GamesJul 14, 2020
# Panzer Corps 2PC865.9[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]SlitherineMar 19, 2020
# Desperados IIIPC868.2[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">Tactics</span>]THQ NordicJun 16, 2020
# Monster TrainPC868.1[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Card Battle</span>]Good Shepherd EntertainmentMay 21, 2020
# CupheadPlayStation 4868.4[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Studio MDHRJul 28, 2020
# HuntdownSwitch868.2[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Coffee Stain StudiosMay 12, 2020
# Cyberpunk 2077PC867.0[<span class="data">Action RPG</span>, <span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Warner Bros. Interactive Entertainment/CD Projekt Red StudioDec 10, 2020
# Risk of Rain 2PC858.3[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>]Hopoo GamesAug 11, 2020
# Deep Rock GalacticPC858.3[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Ghost Ship GamesMay 13, 2020
# Wasteland 3PC857.7[<span class="data">Role-Playing</span>, <span class="data">Western-Style</span>]InXile EntertainmentAug 28, 2020
# 13 Sentinels: Aegis RimPlayStation 4858.9[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>, <span class="data">Adventure</span>, <span class="data">General</span>]AtlusSep 22, 2020
# Bug Fables: The Everlasting SaplingSwitch858.3[<span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]DANGEN EntertainmentMay 28, 2020
# Marvel's Spider-Man: Miles MoralesPlayStation 5857.7[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]PlayStation StudiosNov 12, 2020
# HuntdownPC857.7[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Coffee Stain Studios/Coffee Stain PublishingMay 12, 2020
# WarframePlayStation 5857.8[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>]Digital ExtremesNov 26, 2020
# Planet Coaster: Console EditionXbox One857.4[<span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Business / Tycoon</span>]Frontier Developments/Sold OutNov 10, 2020
# Nioh 2PlayStation 4858.0[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Koei Tecmo GamesMar 13, 2020
# Bayonetta & VanquishPlayStation 4859.3[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]SegaFeb 18, 2020
# Two Point HospitalSwitch858.1[<span class="data">Simulation</span>, <span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Virtual</span>, <span class="data">Career</span>, <span class="data">Business / Tycoon</span>]SegaFeb 25, 2020
# Pikmin 3 DeluxeSwitch858.6[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">General</span>]NintendoOct 30, 2020
# Heroes of Hammerwatch - Ultimate EditionSwitch857.5[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]BlitWorksJul 29, 2020
# Football Manager 2021PC856.4[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Soccer</span>, <span class="data">Management</span>]SegaNov 24, 2020
# Manifold GardenPC857.5[<span class="data">Action Adventure</span>, <span class="data">General</span>]William Chyr Studio LLCOct 20, 2020
# Desperados IIIXbox One857.2[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">Tactics</span>]THQ NordicJun 16, 2020
# Crash Bandicoot 4: It's About TimePlayStation 4858.0[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]ActivisionOct  2, 2020
# Assassin's Creed ValhallaPlayStation 5847.7[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftNov 12, 2020
# Kentucky Route Zero: TV EditionXbox One846.1[<span class="data">Adventure</span>, <span class="data">General</span>]Annapurna InteractiveJan 28, 2020
# Devil May Cry 5: Special EditionXbox Series X847.8[<span class="data">Action Adventure</span>, <span class="data">General</span>]CapcomNov 10, 2020
# Lonely Mountains: DownhillSwitch847.5[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Biking</span>]Image & FormMay  7, 2020
# Thronebreaker: The Witcher TalesSwitch847.3[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Card Battle</span>]CD Projekt Red StudioJan 28, 2020
# If Found...PC846.6[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Annapurna InteractiveMay 19, 2020
# Horizon Zero Dawn: Complete EditionPC847.1[<span class="data">Role-Playing</span>, <span class="data">Action Adventure</span>, <span class="data">Action RPG</span>, <span class="data">Open-World</span>]PlayStation Mobile Inc./Sony Interactive EntertainmentAug  7, 2020
# Wasteland 3Xbox One847.6[<span class="data">Role-Playing</span>, <span class="data">Western-Style</span>]InXile Entertainment/Deep SilverAug 28, 2020
# Planet Coaster: Console EditionXbox Series X845.4[<span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Business / Tycoon</span>]Frontier Developments/Sold OutNov 10, 2020
# WHAT THE GOLF?Switch848.1[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Golf</span>, <span class="data">Arcade</span>]TribandMay 21, 2020
# Assassin's Creed ValhallaXbox Series X847.7[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftNov 10, 2020
# Yakuza: Like a DragonPlayStation 4848.1[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]SegaNov 10, 2020
# Overcooked! All You Can EatPlayStation 5847.0[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]Team17Nov 12, 2020
# Streets of Rage 4PC847.8[<span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">2D</span>]DotEmuApr 30, 2020
# BioShock: The CollectionSwitch848.4[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]2K GamesMay 29, 2020
# The Legend of Heroes: Trails of Cold Steel IIISwitch848.1[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]NIS AmericaJun 30, 2020
# Two Point HospitalXbox One846.6[<span class="data">Simulation</span>, <span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Virtual</span>, <span class="data">Career</span>, <span class="data">Business / Tycoon</span>]SegaFeb 25, 2020
# Lair of the Clockwork GodPC847.5[<span class="data">Adventure</span>, <span class="data">General</span>]Size Five GamesFeb 21, 2020
# Marvel's Spider-Man: Miles MoralesPlayStation 4847.8[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]PlayStation StudiosNov 12, 2020
# SpiritfarerPC848.0[<span class="data">Action Adventure</span>, <span class="data">Sandbox</span>]Thunder Lotus GamesAug 18, 2020
# Sega Ages: Fantasy ZoneSwitch848.2[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Horizontal</span>]SegaJan 23, 2020
# SpiritfarerSwitch848.2[<span class="data">Action Adventure</span>, <span class="data">Sandbox</span>]Thunder Lotus GamesAug 18, 2020
# To the MoonSwitch848.2[<span class="data">Adventure</span>, <span class="data">General</span>]Freebird Games/X.D. Network Inc.Jan 16, 2020
# Resident Evil 3Xbox One846.5[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]CapcomApr  3, 2020
# Genshin ImpactPC844.1[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]miHoYoSep 28, 2020
# Yakuza: Like a DragonXbox Series X838.3[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]SegaNov 10, 2020
# Chicken Police - Paint it RED!Xbox One836.4[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]HandyGamesNov  5, 2020
# Ghost of TsushimaPlayStation 4839.1[<span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Open-World</span>]Sony Interactive EntertainmentJul 17, 2020
# Astro's PlayroomPlayStation 5839.0[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]Sony Interactive Entertainment/PlayStation StudiosNov 12, 2020
# Bayonetta & VanquishXbox One839.3[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]SegaFeb 18, 2020
# Crash Bandicoot 4: It's About TimeXbox One838.3[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]ActivisionOct  2, 2020
# MLB The Show 20PlayStation 4836.3[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Baseball</span>, <span class="data">Sim</span>]SCEE/Sony Interactive EntertainmentMar 13, 2020
# Sackboy: A Big AdventurePlayStation 4837.8[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]Sony Interactive Entertainment/PlayStation StudiosNov 12, 2020
# DIRT 5Xbox One836.1[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]Codemasters/Deep SilverNov  3, 2020
# Observer: System ReduxPC837.0[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">First-Person</span>]Bloober TeamNov 10, 2020
# Knights and BikesSwitch835.5[<span class="data">Action Adventure</span>, <span class="data">General</span>]Double Fine ProductionsFeb  6, 2020
# Mega Man Zero / ZX Legacy CollectionSwitch838.4[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]CapcomFeb 25, 2020
# Yakuza: Like a DragonPC837.9[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]SegaNov 10, 2020
# CreaksPlayStation 4837.1[<span class="data">Adventure</span>, <span class="data">General</span>]Amanita DesignJul 22, 2020
# Super Mega Baseball 3Xbox One837.0[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Baseball</span>, <span class="data">Arcade</span>]Metalhead SoftwareMay 13, 2020
# World of Warcraft: ShadowlandsPC832.8[<span class="data">Role-Playing</span>, <span class="data">Miscellaneous</span>, <span class="data">Massively Multiplayer</span>, <span class="data">Board / Card Game</span>]ActivisionNov 23, 2020
# WRC 9 FIA World Rally ChampionshipXbox One834.8[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]NaconSep  4, 2020
# SpiritfarerPlayStation 4837.9[<span class="data">Action Adventure</span>, <span class="data">Sandbox</span>]Thunder Lotus GamesAug 18, 2020
# Disc RoomPC837.1[<span class="data">Puzzle</span>, <span class="data">Action</span>, <span class="data">General</span>]Devolver DigitalOct 22, 2020
# Chicken Police - Paint it RED!Switch837.2[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]HandyGamesNov  5, 2020
# Sega Ages: Sonic the Hedgehog 2Switch837.9[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]SegaFeb 20, 2020
# Tales From Off-Peak City Vol. 1PC838.3[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">3D</span>, <span class="data">First-Person</span>]Cosmo D Studios/Cosmo D Studios LLCMay 15, 2020
# The Last CampfireSwitch837.7[<span class="data">Puzzle</span>, <span class="data">Action</span>]Hello GamesAug 27, 2020
# Crown TrickPC837.7[<span class="data">Role-Playing</span>, <span class="data">Roguelike</span>]NExT StudiosOct 16, 2020
# Code:Realize - Guardian of RebirthSwitch836.8[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Aksys GamesFeb  6, 2020
# Command & Conquer Remastered CollectionPC828.7[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]Electronic ArtsJun  5, 2020
# Freedom FingerPlayStation 4827.6[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Horizontal</span>]Wide Right InteractiveMar 24, 2020
# Street Fighter V: Champion EditionPlayStation 4826.0[<span class="data">Action</span>, <span class="data">Fighting</span>, <span class="data">2D</span>]CapcomFeb 14, 2020
# No More HeroesSwitch828.1[<span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">3D</span>]XSEED GamesOct 28, 2020
# Streets of Rage 4Xbox One827.9[<span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">2D</span>]DotEmuApr 30, 2020
# Katamari Damacy REROLLPlayStation 4826.2[<span class="data">Action Adventure</span>, <span class="data">General</span>]Bandai Namco GamesNov 20, 2020
# Sam & Max Save the World RemasteredPC825.7[<span class="data">Adventure</span>, <span class="data">Point-and-Click</span>]Skunkape GamesDec  2, 2020
# Yakuza 5 RemasteredPlayStation 4827.9[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]SegaFeb 11, 2020
# SnowRunnerPC826.7[<span class="data">Simulation</span>, <span class="data">Racing</span>, <span class="data">Arcade</span>, <span class="data">Vehicle</span>, <span class="data">Automobile</span>, <span class="data">Civilian</span>]Focus Home InteractiveApr 28, 2020
# SUPERHOT: MIND CONTROL DELETEXbox One825.9[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Tactical</span>]SUPERHOTJul 16, 2020
# CrossCodeSwitch827.7[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Radical Fish Games/DECK13 SpotlightJul  9, 2020
# RuinerSwitch827.8[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>]Devolver DigitalJun 18, 2020
# One Step From EdenPC828.5[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">Defense</span>]Thomas Moon KangMar 26, 2020
# No More Heroes 2: Desperate StruggleSwitch828.0[<span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">3D</span>]XSEED GamesOct 28, 2020
# Gears TacticsXbox Series X827.3[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]Microsoft/Xbox Game StudiosNov 10, 2020
# Desperados IIIPlayStation 4827.9[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">Tactics</span>]THQ NordicJun 16, 2020
# Assassin's Creed ValhallaPC827.5[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftNov 10, 2020
# Bloodstained: Curse of the Moon 2Switch828.1[<span class="data">Action</span>, <span class="data">Action Adventure</span>, <span class="data">Platformer</span>, <span class="data">Open-World</span>, <span class="data">2D</span>]Inti CreatesJul 10, 2020
# HuntdownPlayStation 4827.7[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Coffee Stain StudiosMay 12, 2020
# Super Mario 3D All-StarsSwitch826.4[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]NintendoSep 18, 2020
# Gears 5: HivebustersXbox One827.7[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>]Xbox Game StudiosDec 15, 2020
# Batbarian: Testament of the PrimordialsPC828.6[<span class="data">Action Adventure</span>, <span class="data">General</span>]DANGEN EntertainmentOct 15, 2020
# Under Night In-Birth Exe:Late[cl-r]Switch827.3[<span class="data">Action</span>, <span class="data">Fighting</span>, <span class="data">2D</span>]Aksys GamesFeb 20, 2020
# CreaksPC828.1[<span class="data">Adventure</span>, <span class="data">General</span>]Amanita DesignJul 22, 2020
# Assassin's Creed ValhallaXbox One827.1[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftNov 10, 2020
# The Sims 4: Eco LifestylePC823.5[<span class="data">Simulation</span>, <span class="data">Virtual</span>, <span class="data">Virtual Life</span>]Electronic ArtsJun  5, 2020
# HoraceSwitch827.8[<span class="data">Adventure</span>, <span class="data">General</span>]505 GamesOct 21, 2020
# Borderlands Legendary CollectionSwitch828.2[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]2K GamesMay 29, 2020
# Devil May Cry 3: Special EditionSwitch827.6[<span class="data">Action Adventure</span>, <span class="data">Linear</span>]CapcomFeb 20, 2020
# Streets of Rage 4PlayStation 4828.1[<span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">2D</span>]DotEmu/Limited Run GamesApr 30, 2020
# Two Point HospitalPlayStation 4827.1[<span class="data">Simulation</span>, <span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Virtual</span>, <span class="data">Career</span>, <span class="data">Business / Tycoon</span>]SegaFeb 25, 2020
# EA SPORTS UFC 4Xbox One822.0[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Combat</span>, <span class="data">Boxing / Martial Arts</span>]Electronic ArtsAug 14, 2020
# WRC 9 FIA World Rally ChampionshipPlayStation 5827.5[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]NaconNov 12, 2020
# FilamentPC826.1[<span class="data">Adventure</span>, <span class="data">Puzzle</span>, <span class="data">Action</span>, <span class="data">General</span>]Kasedo GamesApr 23, 2020
# MotoGP 20Xbox One826.4[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Arcade</span>, <span class="data">Automobile</span>]Deep Silver/Milestone S.r.lApr 23, 2020
# Ys OriginSwitch827.9[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]DotEmu/Limited Run GamesOct  1, 2020
# Chicken Police - Paint it RED!PC827.8[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]The Wild GentlemenNov  5, 2020
# Tom Clancy's The Division 2: Warlords of New YorkXbox One822.9[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Tactical</span>]Massive EntertainmentMar  3, 2020
# Clubhouse Games: 51 Worldwide ClassicsSwitch827.7[<span class="data">Miscellaneous</span>, <span class="data">Party / Minigame</span>]NintendoJun  5, 2020
# Sakuna: Of Rice and RuinPC827.3[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]XSEED GamesNov 10, 2020
# Welcome to ElkPC827.2[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Point-and-Click</span>]Triple Topping GamesSep 17, 2020
# Pixel Ripped 1995PlayStation 4826.6[<span class="data">Miscellaneous</span>, <span class="data">Party / Minigame</span>]Arvore Immersive Experiences/LLCMay 12, 2020
# Call of the SeaXbox One817.7[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">First-Person</span>]Raw FuryDec  8, 2020
# FuserPlayStation 4817.2[<span class="data">Action</span>, <span class="data">Rhythm</span>, <span class="data">Music</span>]NCSOFTNov 10, 2020
# Tokyo Mirage Sessions #FE EncoreSwitch816.3[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]NintendoJan 17, 2020
# Paradise KillerSwitch817.9[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Fellow TravellerSep  4, 2020
# Remnant: From the Ashes - Swamps of CorsusPC816.2[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>]Perfect World EntertainmentApr 28, 2020
# GhostrunnerPC818.2[<span class="data">Action</span>, <span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]505 Games/All in! GamesOct 27, 2020
# Jet LancerSwitch81tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Vertical</span>]Armor GamesMay 12, 2020
# Hunt: ShowdownPlayStation 4816.9[<span class="data">Sci-Fi</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>, <span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Tactical</span>]Crytek/Koch Media/Deep SilverFeb 18, 2020
# Aviary Attorney: Definitive EditionSwitch818.0[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Vertical ReachJan 30, 2020
# Paradise KillerPC817.5[<span class="data">General</span>, <span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Fellow TravellerSep  4, 2020
# The PedestrianPC817.6[<span class="data">Puzzle</span>, <span class="data">Action</span>]Skookum Arts LLC/Skookum ArtsJan 29, 2020
# SuzerainPC818.0[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">4X</span>]Fellow TravellerDec  4, 2020
# BloodrootsPlayStation 4816.8[<span class="data">Action</span>, <span class="data">Beat-'Em-Up</span>, <span class="data">3D</span>]Paper CultFeb 28, 2020
# Operencia: The Stolen SunSwitch817.7[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Zen StudiosMar 31, 2020
# WunderlingSwitch818.0[<span class="data">Action</span>, <span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]RetroidMar  5, 2020
# Rune Factory 4 SpecialSwitch818.0[<span class="data">Role-Playing</span>, <span class="data">Strategy</span>, <span class="data">General</span>, <span class="data">Action RPG</span>]XSEED GamesFeb 25, 2020
# FuserXbox One817.8[<span class="data">Action</span>, <span class="data">Rhythm</span>, <span class="data">Music</span>]NCSOFTNov 10, 2020
# DIRT 5Xbox Series X816.2[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]Codemasters/Deep SilverNov 10, 2020
# SnowRunnerXbox One817.0[<span class="data">Simulation</span>, <span class="data">Racing</span>, <span class="data">Arcade</span>, <span class="data">Vehicle</span>, <span class="data">Automobile</span>, <span class="data">Civilian</span>]Focus Home InteractiveApr 28, 2020
# SnowRunnerPlayStation 4817.0[<span class="data">Simulation</span>, <span class="data">Racing</span>, <span class="data">Arcade</span>, <span class="data">Vehicle</span>, <span class="data">Automobile</span>, <span class="data">Civilian</span>]Focus Home InteractiveApr 28, 2020
# CrossCodePlayStation 4817.3[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]DECK13 SpotlightJul  9, 2020
# The Walking Dead: Saints & SinnersPC818.0[<span class="data">Action</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Survival</span>]Skydance InteractiveJan 23, 2020
# Going UnderSwitch817.1[<span class="data">Action Adventure</span>, <span class="data">General</span>]Team17Sep 24, 2020
# Genshin ImpactPlayStation 4814.6[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]miHoYoSep 28, 2020
# The Legend of Heroes: Trails of Cold Steel IVPlayStation 4818.6[<span class="data">Role-Playing</span>, <span class="data">Japanese-Style</span>]NIS AmericaOct 27, 2020
# VisagePC814.1[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]SadSquare StudioOct 29, 2020
# EmbraceletSwitch817.6[<span class="data">Adventure</span>, <span class="data">Puzzle</span>, <span class="data">Action</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]machineboySep 24, 2020
# Neon AbyssXbox One816.9[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Team17Jul 14, 2020
# The PathlessPC817.5[<span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Open-World</span>]Giant SquidNov 12, 2020
# NecrobaristaPC816.1[<span class="data">Action</span>, <span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Visual Novel</span>]Route 59 Games/Route 59Jul 22, 2020
# Immortals Fenyx RisingXbox Series X817.7[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftDec  3, 2020
# PHOGS!Xbox One815.6[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]Coatsink SoftwareDec  3, 2020
# Nowhere ProphetSwitch816.3[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Card Battle</span>]No More RobotsJul 30, 2020
# Get PackedStadia817.7[<span class="data">Puzzle</span>, <span class="data">Action</span>, <span class="data">General</span>]Coatsink SoftwareApr 28, 2020
# Creature in the WellPlayStation 4816.7[<span class="data">Action Adventure</span>, <span class="data">General</span>]MWM InteractiveMar 27, 2020
# Planet Coaster: Console EditionPlayStation 5816.2[<span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Business / Tycoon</span>]Frontier Developments/Sold Out Software/Sold OutNov 12, 2020
# Disc RoomSwitch81tbd[<span class="data">Puzzle</span>, <span class="data">Action</span>, <span class="data">General</span>]Devolver DigitalOct 22, 2020
# Fall GuysPlayStation 4816.9[<span class="data">Miscellaneous</span>, <span class="data">Party / Minigame</span>]Devolver DigitalAug  4, 2020
# WRC 9 FIA World Rally ChampionshipPlayStation 4815.5[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]Bigben Interactive/NaconSep  4, 2020
# AVICII Invector Encore EditionSwitch818.0[<span class="data">Action</span>, <span class="data">Rhythm</span>, <span class="data">Music</span>]Wired ProductionsSep  8, 2020
# Catherine: Full BodySwitch808.1[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]AtlusJul  7, 2020
# Gears TacticsPC807.5[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]Microsoft Game StudiosApr 28, 2020
# The Last CampfirePC808.4[<span class="data">Adventure</span>, <span class="data">Puzzle</span>, <span class="data">Action</span>, <span class="data">General</span>]Hello GamesAug 27, 2020
# Metro ReduxSwitch808.3[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]Deep SilverFeb 28, 2020
# Vitamin ConnectionSwitch807.5[<span class="data">Action</span>, <span class="data">General</span>]Limited Run GamesJan 17, 2020
# Amnesia: RebirthPC806.4[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]Frictional GamesOct 20, 2020
# Assassin's Creed ValhallaPlayStation 4807.3[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftNov 10, 2020
# Monster Prom 2: Monster CampPC807.5[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Beautiful GlitchOct 23, 2020
# Under Night In-Birth Exe:Late[cl-r]PlayStation 4806.4[<span class="data">Action</span>, <span class="data">Fighting</span>, <span class="data">2D</span>]Aksys GamesFeb 20, 2020
# Going UnderPlayStation 4806.3[<span class="data">Action Adventure</span>, <span class="data">General</span>]Team17Sep 24, 2020
# Sakuna: Of Rice and RuinSwitch808.2[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]XSEED GamesNov 10, 2020
# Crown TrickSwitch807.7[<span class="data">Role-Playing</span>, <span class="data">Roguelike</span>]NExT StudiosOct 16, 2020
# Mega Man Zero / ZX Legacy CollectionXbox One807.9[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]CapcomFeb 25, 2020
# Super Mega Baseball 3PlayStation 4806.9[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Baseball</span>, <span class="data">Arcade</span>]Metalhead SoftwareMay 13, 2020
# Neon AbyssPlayStation 4807.4[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Veewo GamesJul 14, 2020
# NBA 2K21Xbox Series X804.5[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Basketball</span>, <span class="data">Arcade</span>]2K GamesNov 10, 2020
# Bloodstained: Curse of the Moon 2PC807.7[<span class="data">Action</span>, <span class="data">Action Adventure</span>, <span class="data">Platformer</span>, <span class="data">Open-World</span>, <span class="data">2D</span>]Inti CreatesJul 10, 2020
# Sega Ages: Thunder Force ACSwitch80tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Horizontal</span>]SegaMay 28, 2020
# DIRT 5PlayStation 5805.7[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]Codemasters/Deep SilverNov 12, 2020
# DOOM EternalSwitch808.6[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Bethesda SoftworksDec  8, 2020
# ScourgeBringerSwitch806.8[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Oct 21/2020Oct 21, 2020
# ForegoneXbox One80tbd[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Big Blue Bubble Inc.Oct 13, 2020
# SuperliminalPlayStation 4806.7[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">First-Person</span>]Pillow Castle GamesJul  7, 2020
# Mr. Driller: Drill LandSwitch807.4[<span class="data">Puzzle</span>, <span class="data">Action</span>]Bandai Namco GamesJun 25, 2020
# Wintermoor Tactics ClubPC805.4[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]Versus Evil/EVCMay  5, 2020
# ValorantPC804.8[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Tactical</span>]Riot GamesJun  2, 2020
# Puyo Puyo Tetris 2Switch808.2[<span class="data">Puzzle</span>, <span class="data">Matching</span>]SegaDec  8, 2020
# Fall GuysPC807.1[<span class="data">Miscellaneous</span>, <span class="data">Party / Minigame</span>]Devolver DigitalAug  4, 2020
# Puyo Puyo Tetris 2PlayStation 4806.6[<span class="data">Puzzle</span>, <span class="data">Matching</span>]SegaDec  8, 2020
# FuserSwitch807.0[<span class="data">Action</span>, <span class="data">Rhythm</span>, <span class="data">Music</span>]NCSOFTNov  9, 2020
# FaeriaSwitch806.8[<span class="data">Miscellaneous</span>, <span class="data">Board / Card Game</span>]Versus Evil/Abrakam SAAug 13, 2020
# Mega Man Zero / ZX Legacy CollectionPlayStation 4808.2[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]CapcomFeb 25, 2020
# Pumpkin JackXbox One806.8[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]Headup GamesOct 23, 2020
# Super Bomberman R OnlineStadia807.2[<span class="data">Puzzle</span>, <span class="data">Action</span>]KonamiSep  1, 2020
# Telling LiesSwitch806.4[<span class="data">Adventure</span>, <span class="data">General</span>]Annapurna InteractiveApr 28, 2020
# Alwa's LegacySwitch807.8[<span class="data">Action</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">2D</span>, <span class="data">Metroidvania</span>]Elden PixelsSep 29, 2020
# Shantae and the Seven SirensPC806.4[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]WayForwardMay 28, 2020
# WRC 9 FIA World Rally ChampionshipPC805.7[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]NaconSep  3, 2020
# SuperliminalXbox One809.6[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">First-Person</span>]Pillow Castle GamesJul  7, 2020
# VisagePlayStation 4805.9[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]SadSquare StudioOct 31, 2020
# Paper Mario: The Origami KingSwitch807.0[<span class="data">Role-Playing</span>, <span class="data">General</span>]NintendoJul 17, 2020
# Call of Duty: WarzonePC803.2[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Tactical</span>]ActivisionMar 10, 2020
# Total War: Three Kingdoms - Mandate of HeavenPC806.8[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">General</span>]SegaJan 16, 2020
# The Sims 4: Snowy EscapePC804.9[<span class="data">Simulation</span>, <span class="data">Virtual</span>, <span class="data">Virtual Life</span>]Electronic ArtsNov 13, 2020
# If Found...Switch807.7[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Annapurna InteractiveOct 22, 2020
# Total War: Three Kingdoms - A World BetrayedPC806.2[<span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">General</span>]SegaMar 19, 2020
# Telling LiesPlayStation 4795.6[<span class="data">Adventure</span>, <span class="data">General</span>]Annapurna InteractiveApr 28, 2020
# Wide Ocean Big JacketSwitch797.2[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Point-and-Click</span>, <span class="data">Third-Person</span>]Tender ClawsFeb  4, 2020
# Atelier Dusk Trilogy Deluxe PackPlayStation 4797.2[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]Koei Tecmo GamesJan 14, 2020
# DOOM Eternal: The Ancient Gods Part OnePC797.9[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Bethesda SoftworksOct 20, 2020
# IndivisibleSwitch797.4[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]505 GamesApr 28, 2020
# Shantae and the Seven SirensSwitch796.5[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]WayForwardMay 28, 2020
# art of rallyPC796.8[<span class="data">Racing</span>, <span class="data">Arcade</span>, <span class="data">Automobile</span>]Funselektor Labs Inc.Sep 23, 2020
# Star Wars: SquadronsPC795.8[<span class="data">Simulation</span>, <span class="data">Space</span>, <span class="data">Combat</span>]Electronic ArtsOct  1, 2020
# Hotshot RacingXbox One797.8[<span class="data">Racing</span>, <span class="data">Arcade</span>, <span class="data">Automobile</span>]Sumo DigitalSep 10, 2020
# Naruto Shippuden: Ultimate Ninja Storm 4 - Road to BorutoSwitch797.6[<span class="data">Action</span>, <span class="data">Fighting</span>, <span class="data">3D</span>]Bandai Namco GamesApr 24, 2020
# Planet Coaster: Console EditionPlayStation 4795.7[<span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Business / Tycoon</span>]Frontier Developments/Sold OutNov 10, 2020
# Cafe EnchanteSwitch797.2[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Aksys GamesNov  5, 2020
# Among UsSwitch796.5[<span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Survival</span>]InnerslothDec 15, 2020
# Five DatesPlayStation 4796.3[<span class="data">Adventure</span>, <span class="data">Visual Novel</span>]Wales InteractiveNov 17, 2020
# EarthNightPlayStation 4796.8[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]cleaversoftJan 23, 2020
# Stories UntoldSwitch797.8[<span class="data">Adventure</span>, <span class="data">Text</span>]Devolver DigitalJan 16, 2020
# Immortals Fenyx RisingPC797.5[<span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Open-World</span>]UbisoftDec  3, 2020
# Hatsune Miku: Project Diva MegaMixSwitch798.1[<span class="data">Action</span>, <span class="data">Rhythm</span>, <span class="data">Music</span>]SegaMay 15, 2020
# CartoSwitch796.6[<span class="data">Strategy</span>, <span class="data">Adventure</span>, <span class="data">General</span>]Humble Bundle/Humble GamesOct 27, 2020
# Project WarlockXbox One796.2[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Crunching KoalasJun 12, 2020
# Pirates OutlawsPC798.2[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Card Battle</span>]Fabled GameApr 13, 2020
# When The Past Was AroundSwitch797.4[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Point-and-Click</span>]Chorus WorldwideDec 15, 2020
# Sniper Elite 4Switch798.3[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Tactical</span>]Rebellion/Sold OutNov 17, 2020
# Kingdom Hearts: Melody of MemorySwitch798.0[<span class="data">Action</span>, <span class="data">Rhythm</span>, <span class="data">Music</span>]Square EnixNov 13, 2020
# BugsnaxPlayStation 4797.7[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Open-World</span>, <span class="data">First-Person</span>]Young Horses/Inc/FangamerNov 12, 2020
# The Walking Dead: Saints & SinnersPlayStation 4798.2[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]Skydance InteractiveMay  5, 2020
# PHOGS!PlayStation 4796.5[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]Coatsink SoftwareDec  3, 2020
# Mortal Kombat 11: AftermathXbox One796.9[<span class="data">Action</span>, <span class="data">Fighting</span>, <span class="data">2D</span>]Warner Bros. Interactive EntertainmentMay 26, 2020
# Sackboy: A Big AdventurePlayStation 5798.6[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]Sony Interactive Entertainment/PlayStation StudiosNov 12, 2020
# Call of Duty: WarzoneXbox One794.3[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Tactical</span>]ActivisionMar 10, 2020
# The LongingPC797.6[<span class="data">Adventure</span>, <span class="data">General</span>]Studio SeufzMar  5, 2020
# ...
# TchiaPC776.1[<span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Open-World</span>]Awaceb/Kowloon Nights/Kepler InteractiveMar 21, 2023
# TchiaPlayStation 5777.0[<span class="data">General</span>, <span class="data">Action Adventure</span>, <span class="data">Open-World</span>]Awaceb/Kepler InteractiveMar 21, 2023
# Vengeful Guardian: MoonriderPC776.5[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]The Arcade CrewJan 12, 2023
# One Piece OdysseyPC775.7[<span class="data">Role-Playing</span>, <span class="data">General</span>, <span class="data">Japanese-Style</span>]Bandai Namco GamesJan 12, 2023
# MLB The Show 23PlayStation 5798.5[<span class="data">Sports</span>, <span class="data">Team</span>, <span class="data">Baseball</span>, <span class="data">Sim</span>]Sony Interactive EntertainmentMar 24, 2023
# The PathlessSwitch77tbd[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]Annapurna InteractiveFeb  2, 2023
# Tails: The Backbone PreludesPC77tbd[<span class="data">Adventure</span>, <span class="data">General</span>]Raw FuryFeb  2, 2023
# SEASON: A letter to the futurePlayStation 5766.6[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]Covalent MediaJan 31, 2023
# Akka ArrhPC76tbd[<span class="data">Action</span>, <span class="data">Arcade</span>]AtariFeb 21, 2023
# TentacularPlayStation 5765.5[<span class="data">Puzzle</span>, <span class="data">Action</span>]Devolver Digital/FirepunchdFeb 22, 2023
# DC's Justice League: Cosmic ChaosPlayStation 576tbd[<span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Open-World</span>]Outright GamesMar 10, 2023
# Grim Guardians: Demon PurgeSwitch76tbd[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">Metroidvania</span>]Inti CreatesFeb 23, 2023
# SpellForce: Conquest of EoPC767.4[<span class="data">General</span>, <span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]THQ NordicFeb  3, 2023
# Vengeful Guardian: MoonriderPlayStation 5767.4[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]The Arcade CrewJan 12, 2023
# Wild HeartsXbox Series X768.6[<span class="data">Role-Playing</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Action RPG</span>]Electronic ArtsFeb 17, 2023
# PowerWash SimulatorPlayStation 5753.3[<span class="data">Simulation</span>, <span class="data">Virtual</span>, <span class="data">Career</span>]Square EnixJan 31, 2023
# Atomic HeartPC757.6[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Mundfish/Focus EntertainmentFeb 21, 2023
# Fashion Police SquadXbox Series X75tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]No More RobotsFeb  2, 2023
# Wild HeartsPC758.4[<span class="data">Action Adventure</span>, <span class="data">General</span>, <span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Electronic ArtsFeb 17, 2023
# Figment 2: Creed ValleyPC75tbd[<span class="data">Action</span>, <span class="data">Action Adventure</span>, <span class="data">General</span>]Bedtime Digital GamesMar  9, 2023
# Zombieland: Headshot Fever ReloadedPlayStation 575tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Light Gun</span>]XR GamesFeb 22, 2023
# Kayak VR: MiragePlayStation 5747.5[<span class="data">Sports</span>, <span class="data">Individual</span>, <span class="data">Other</span>]Better Than LifeFeb 22, 2023
# Raiden IV x Mikado RemixPlayStation 574tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Vertical</span>]NIS America/UFO Interactive/GamestopJan 31, 2023
# 9 Years of ShadowsPC748.2[<span class="data">Action</span>, <span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">Metroidvania</span>]None/yet./Freedom GamesMar 27, 2023
# What The Bat?PlayStation 574tbd[<span class="data">Action</span>, <span class="data">General</span>]TribandFeb 22, 2023
# The Walking Dead: Saints & Sinners - Chapter 2: RetributionPlayStation 5747.7[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Skydance Interactive/Skybound GamesMar 21, 2023
# The Last WorkerPlayStation 574tbd[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">First-Person</span>]Wired ProductionsMar 30, 2023
# Children of SilentownPC747.0[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Point-and-Click</span>]Daedalic Entertainment/Elf GamesJan 11, 2023
# One Piece OdysseyPlayStation 5746.8[<span class="data">Role-Playing</span>, <span class="data">General</span>, <span class="data">Japanese-Style</span>]Bandai Namco GamesJan 13, 2023
# Life is Strange 2Switch742.5[<span class="data">Action Adventure</span>, <span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]Square EnixFeb  2, 2023
# ATONE: Heart of the Elder TreeSwitch73tbd[<span class="data">Action Adventure</span>, <span class="data">General</span>]Untold TalesJan 27, 2023
# Breakers CollectionPlayStation 573tbd[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]QUByte Interactive/Strictly Limited GamesJan 12, 2023
# Fatal Frame: Mask of the Lunar EclipseSwitch738.9[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]Koei Tecmo GamesMar  9, 2023
# SpongeBob SquarePants: The Cosmic ShakeSwitch737.9[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]THQ NordicJan 31, 2023
# Remnant: From the AshesSwitch73tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Third-Person</span>, <span class="data">Arcade</span>]Perfect World Entertainment/THQ NordicMar 21, 2023
# Clash: Artifacts of ChaosPC735.9[<span class="data">Action Adventure</span>, <span class="data">General</span>]NaconMar  9, 2023
# Ten DatesPC73tbd[<span class="data">Adventure</span>, <span class="data">General</span>, <span class="data">Visual Novel</span>]Wales InteractiveFeb 14, 2023
# StorytellerPC725.8[<span class="data">Miscellaneous</span>, <span class="data">General</span>, <span class="data">Puzzle</span>, <span class="data">Puzzle</span>, <span class="data">General</span>]Annapurna InteractiveMar 23, 2023
# Wonder Boy Anniversary CollectionSwitch72tbd[<span class="data">Miscellaneous</span>, <span class="data">Compilation</span>]Bliss BrainJan 26, 2023
# Onion AssaultSwitch72tbd[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">2D</span>]Horberg ProductionsJan 26, 2023
# Akka ArrhSwitch72tbd[<span class="data">Action</span>, <span class="data">Arcade</span>]AtariFeb 21, 2023
# MahokenshiPC726.1[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]Iceberg Interactive/GameSourceStudioJan 24, 2023
# The Outer Worlds: Spacer's Choice EditionPlayStation 5724.3[<span class="data">Role-Playing</span>, <span class="data">Western-Style</span>]Obsidian Entertainment/Private DivisionMar  7, 2023
# Star Wars: Tales from the Galaxy's Edge - Enhanced EditionPlayStation 5715.0[<span class="data">Action Adventure</span>, <span class="data">General</span>]Disney Interactive Studios/Disney Electronic Content/Inc.Feb 22, 2023
# StorytellerSwitch734.8[<span class="data">Puzzle</span>, <span class="data">General</span>]Annapurna InteractiveMar 23, 2023
# OddBallersSwitch71tbd[<span class="data">Miscellaneous</span>, <span class="data">Party / Minigame</span>]UbisoftJan 26, 2023
# Atomic HeartPlayStation 5716.9[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]Mundfish/Focus EntertainmentFeb 21, 2023
# SpongeBob SquarePants: The Cosmic ShakePC717.1[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]THQ NordicJan 31, 2023
# ElderandPC717.2[<span class="data">General</span>, <span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">Metroidvania</span>]Graffiti Games/MantraFeb 16, 2023
# Grim Guardians: Demon PurgePlayStation 571tbd[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">Metroidvania</span>]PQube/Inti CreatesFeb 23, 2023
# Destiny 2: LightfallPlayStation 5703.2[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]BungieFeb 28, 2023
# Destiny 2: LightfallXbox Series X702.1[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">First-Person</span>, <span class="data">Arcade</span>]BungieFeb 28, 2023
# Deliver Us MarsPC707.6[<span class="data">Adventure</span>, <span class="data">General</span>]Frontier FoundryFeb  2, 2023
# SpongeBob SquarePants: The Cosmic ShakePlayStation 4698.4[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]THQ NordicJan 31, 2023
# Scars AboveXbox Series X696.4[<span class="data">Action Adventure</span>, <span class="data">General</span>]Deep Silver/Prime MatterFeb 28, 2023
# Deliver Us MarsXbox Series X696.8[<span class="data">Adventure</span>, <span class="data">General</span>]Frontier FoundryFeb  2, 2023
# Monster Energy Supercross - The Official Videogame 6PlayStation 569tbd[<span class="data">Racing</span>, <span class="data">Simulation</span>, <span class="data">Automobile</span>]Milestone S.r.lMar  9, 2023
# Lone RuinSwitch695.0[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Top-Down</span>]Super Rare OriginalsJan 12, 2023
# Fatal Frame: Mask of the Lunar EclipsePC698.3[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]Koei Tecmo GamesMar  9, 2023
# Scars AbovePC697.5[<span class="data">Action Adventure</span>, <span class="data">General</span>]Prime MatterFeb 28, 2023
# The Dark Pictures: Switchback VRPlayStation 5696.3[<span class="data">Action Adventure</span>, <span class="data">Survival</span>, <span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Light Gun</span>]Supermassive GamesMar 16, 2023
# Tales of Symphonia RemasteredPlayStation 4682.8[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Bandai Namco GamesFeb 17, 2023
# Deliver Us MarsPlayStation 5684.3[<span class="data">Adventure</span>, <span class="data">General</span>]Frontier FoundryFeb  2, 2023
# SpongeBob SquarePants: The Cosmic ShakeXbox One685.9[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]THQ NordicJan 31, 2023
# BlancPC682.4[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]Gearbox PublishingFeb 14, 2023
# Fatal Frame: Mask of the Lunar EclipsePlayStation 5678.3[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]Koei Tecmo GamesMar  9, 2023
# Destiny 2: LightfallPC662.3[<span class="data">Action</span>, <span class="data">First-Person</span>, <span class="data">Shooter</span>, <span class="data">Arcade</span>]BungieFeb 28, 2023
# Little Witch NobetaPlayStation 465tbd[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Idea Factory/Pupuya GamesMar  7, 2023
# WarlanderPC657.6[<span class="data">Action</span>, <span class="data">General</span>, <span class="data">Strategy</span>, <span class="data">Real-Time</span>, <span class="data">MOBA</span>]PLAIONJan 24, 2023
# Neptunia: Sisters vs. SistersPlayStation 5654.9[<span class="data">Role-Playing</span>, <span class="data">General</span>]Idea FactoryJan 24, 2023
# BlancSwitch654.4[<span class="data">Adventure</span>, <span class="data">3D</span>, <span class="data">Third-Person</span>]Gearbox PublishingFeb 14, 2023
# Scars AbovePlayStation 5646.8[<span class="data">Action Adventure</span>, <span class="data">General</span>]Deep Silver/Prime MatterFeb 28, 2023
# Fatal Frame: Mask of the Lunar EclipseXbox Series X648.3[<span class="data">Action Adventure</span>, <span class="data">Survival</span>]Koei Tecmo GamesMar  9, 2023
# ForspokenPlayStation 5643.5[<span class="data">Role-Playing</span>, <span class="data">Action Adventure</span>, <span class="data">Action RPG</span>, <span class="data">Open-World</span>]Square EnixJan 24, 2023
# Tales of Symphonia RemasteredSwitch633.0[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Bandai Namco GamesFeb 17, 2023
# Lone RuinPC62tbd[<span class="data">Action</span>, <span class="data">Shooter</span>, <span class="data">Shoot-'Em-Up</span>, <span class="data">Top-Down</span>]Super Rare Games/Super Rare OriginalsJan 12, 2023
# Digimon World: Next OrderSwitch626.3[<span class="data">Role-Playing</span>, <span class="data">Trainer</span>]Bandai Namco GamesFeb 22, 2023
# Redemption ReapersPC62tbd[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Tactics</span>]Binary Haze InteractiveFeb 22, 2023
# Mato AnomaliesPC61tbd[<span class="data">Role-Playing</span>, <span class="data">General</span>, <span class="data">Japanese-Style</span>]Prime MatterMar 10, 2023
# Mato AnomaliesPlayStation 560tbd[<span class="data">Role-Playing</span>, <span class="data">General</span>, <span class="data">Japanese-Style</span>]Prime Matter/PLAIONMar 10, 2023
# Wanted: DeadXbox Series X607.1[<span class="data">Action Adventure</span>, <span class="data">General</span>]110 IndustriesFeb 14, 2023
# Clive 'N' WrenchPlayStation 560tbd[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]Numskull GamesFeb 24, 2023
# RavenboundPC59tbd[<span class="data">Role-Playing</span>, <span class="data">Action RPG</span>]Systemic ReactionMar 30, 2023
# Wanted: DeadPC585.9[<span class="data">Action Adventure</span>, <span class="data">General</span>]110 IndustriesFeb 14, 2023
# The Settlers: New AlliesPC582.5[<span class="data">Strategy</span>, <span class="data">Management</span>, <span class="data">Government</span>]UbisoftFeb 17, 2023
# Wanted: DeadPlayStation 5576.9[<span class="data">Action Adventure</span>, <span class="data">General</span>]110 IndustriesFeb 14, 2023
# Blood Bowl IIIPC561.5[<span class="data">Sports</span>, <span class="data">Football</span>, <span class="data">Arcade</span>, <span class="data">Team</span>]Bigben Interactive/NaconFeb 23, 2023
# Nadir: A Grimdark Deck BuilderSwitch55tbd[<span class="data">Strategy</span>, <span class="data">Turn-Based</span>, <span class="data">Card Battle</span>]Black Eye GamesFeb  7, 2023
# Colossal CavePC546.0[<span class="data">Action Adventure</span>, <span class="data">Adventure</span>, <span class="data">General</span>]Cygnus EntertainmentJan 19, 2023
# Clive 'N' WrenchSwitch51tbd[<span class="data">Action</span>, <span class="data">Platformer</span>, <span class="data">3D</span>]Numskull GamesFeb 24, 2023
# Crime Boss: Rockay CityPC485.7[<span class="data">Action Adventure</span>, <span class="data">Open-World</span>]505 GamesMar 28, 2023
# 3083
# 3083
# 3083
# 3083
# 3083
# 3083
# 3083

# %%
Data2020_2023 = pd.DataFrame({'Game Title':game_title,
                            'Game Publisher':game_pulisher,
                            'Game Platform':game_platform,
                            'Game Genre':game_genre,
                            'Game Release Date':game_date,
                            'Critic Score':critic_score,
                            'User Score':user_score,
                            })
Data2020_2023.dropna(inplace=True)
Data2020_2023['Game Release Date'] = pd.to_datetime(Data2020_2023['Game Release Date'])
Data2020_2023['Year'] = Data2020_2023['Game Release Date'].dt.year
Data2020_2023.dropna(inplace=True)
Data2020_2023
# Out:
#                           Game Title                       Game Publisher  \
# 0                    Persona 5 Royal                                Atlus
# 1             The Last of Us Part II  SCEA/Sony Interactive Entertainment
# 2                              Hades                     Supergiant Games
# 3                    Half-Life: Alyx                       Valve Software
# 4      Ori and the Will of the Wisps       Microsoft Game Studios/iam8bit
# ...                              ...                                  ...
# 3078                  Blood Bowl III             Bigben Interactive/Nacon
# 3079  Nadir: A Grimdark Deck Builder                      Black Eye Games
# 3080                   Colossal Cave                 Cygnus Entertainment
# 3081                Clive 'N' Wrench                       Numskull Games
# 3082         Crime Boss: Rockay City                            505 Games
#
#       Game Platform                                         Game Genre  \
# 0     PlayStation 4                        Role-Playing/Japanese-Style
# 1     PlayStation 4                  General/Action Adventure/Survival
# 2            Switch  Role-Playing/Action Adventure/General/Linear/R...
# 3                PC                 Action/Shooter/First-Person/Arcade
# 4            Switch                 Action/Platformer/2D//Metroidvania
# ...             ...                                                ...
# 3078             PC                        Sports/Football/Arcade/Team
# 3079         Switch                    Strategy/Turn-Based/Card Battle
# 3080             PC                 Action Adventure/Adventure/General
# 3081         Switch                               Action/Platformer/3D
# 3082             PC                        Action Adventure/Open-World
#
#      Game Release Date Critic Score User Score    Year
# 0           2020-03-31           95        8.5  2020.0
# 1           2020-06-19           93        5.8  2020.0
# 2           2020-09-17           93        9.0  2020.0
# 3           2020-03-23           93        9.2  2020.0
# 4           2020-09-17           93        8.7  2020.0
# ...                ...          ...        ...     ...
# 3078        2023-02-23           56        1.5  2023.0
# 3079        2023-02-07           55        tbd  2023.0
# 3080        2023-01-19           54        6.0  2023.0
# 3081        2023-02-24           51        tbd  2023.0
# 3082        2023-03-28           48        5.7  2023.0
#
# [3081 rows x 8 columns]

# %%
Data2020_2023.to_csv('Data2020_2023.csv',index=False)

# %%
urls2020 = pd.read_csv('urls_2020_.csv',header=0)
urls2021 = pd.read_csv('urls_2021_.csv',header=0)
urls2022 = pd.read_csv('urls_2022_.csv',header=0)
urls2023 = pd.read_csv('urls_2023_.csv',header=0)
urls2020.info()
urls2021.info()
urls2022.info()
urls2023.info()

urls2020_2023 = pd.concat([urls2020,urls2021,urls2022,urls2023],axis=0)
urls2020_2023 = urls2020_2023.reset_index(drop=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1092 non-null   int64
#  1   url         1092 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 17.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 986 entries, 0 to 985
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  986 non-null    int64
#  1   url         986 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 15.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  831 non-null    int64
#  1   url         831 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 13.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  174 non-null    int64
#  1   url         174 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.8+ KB

# %%
urls2020_2023.to_csv('urls2020_2023.csv',index=False)

# %%
Data2017 = pd.read_csv('Data2017.csv',header=0)
Data2018 = pd.read_csv('Data2018.csv',header=0)
Data2019 = pd.read_csv('Data2019.csv',header=0)
Data2020_2023 = pd.read_csv('Data2020_2023.csv',header=0)

Data2017.info()
Data2018.info()
Data2019.info()
Data2020_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1056 entries, 0 to 1055
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Game Title         1056 non-null   object
#  1   Game Publisher     1056 non-null   object
#  2   Game Platform      1056 non-null   object
#  3   Game Genre         1056 non-null   object
#  4   Game Release Date  1056 non-null   object
#  5   Critic Score       1056 non-null   int64
#  6   User Score         1056 non-null   object
#  7   Year               1056 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 66.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1151 entries, 0 to 1150
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Game Title         1151 non-null   object
#  1   Game Publisher     1151 non-null   object
#  2   Game Platform      1151 non-null   object
#  3   Game Genre         1151 non-null   object
#  4   Game Release Date  1151 non-null   object
#  5   Critic Score       1151 non-null   int64
#  6   User Score         1151 non-null   object
#  7   Year               1151 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 72.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Game Title         1016 non-null   object
#  1   Game Publisher     1016 non-null   object
#  2   Game Platform      1016 non-null   object
#  3   Game Genre         1016 non-null   object
#  4   Game Release Date  1016 non-null   object
#  5   Critic Score       1016 non-null   int64
#  6   User Score         1016 non-null   object
#  7   Year               1016 non-null   int64
# dtypes: int64(2), object(6)
# memory usage: 63.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Game Title         3081 non-null   object
#  1   Game Publisher     3081 non-null   object
#  2   Game Platform      3081 non-null   object
#  3   Game Genre         3081 non-null   object
#  4   Game Release Date  3081 non-null   object
#  5   Critic Score       3081 non-null   int64
#  6   User Score         3080 non-null   object
#  7   Year               3081 non-null   float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 192.7+ KB

# %%
Dataall = pd.concat([Data2017,Data2018,Data2019,Data2020_2023],axis=0)
Dataall = Dataall.sort_values(by=['Game Release Date'],ascending = True, inplace=False).reset_index(drop=True)
print(Dataall)
Dataall.to_csv('Dataall.csv',index=False)
# Out:
#                                              Game Title  \
# 0                             Star Wars: Battlefront II
# 1                             Milkmaid of the Milky Way
# 2     Hatsune Miku: Project Diva Future Tone - Futur...
# 3     Hatsune Miku: Project Diva Future Tone - Color...
# 4                                             Nevermind
# ...                                                 ...
# 6299                                             DREDGE
# 6300                                    The Last Worker
# 6301                                             DREDGE
# 6302                                         Ravenbound
# 6303                              GrimGrimoire OnceMore
#
#                Game Publisher  Game Platform  \
# 0                   LucasArts             PC
# 1                  machineboy             PC
# 2                        Sega  PlayStation 4
# 3                        Sega  PlayStation 4
# 4              Flying Mollusk       Xbox One
# ...                       ...            ...
# 6299   Team17/Fireshine Games  PlayStation 5
# 6300        Wired Productions  PlayStation 5
# 6301  Team17/Black Salt Games             PC
# 6302        Systemic Reaction             PC
# 6303              NIS America         Switch
#
#                                              Game Genre Game Release Date  \
# 0     Action/Shooter/Shooter/First-Person/Sci-Fi/Sci...        2005-10-31
# 1                             Adventure/Point-and-Click        2017-01-04
# 2                                   Action/Rhythm/Music        2017-01-10
# 3                                   Action/Rhythm/Music        2017-01-10
# 4     Action Adventure/Adventure/3D/Linear/First-Person        2017-01-11
# ...                                                 ...               ...
# 6299                                  Adventure/General        2023-03-30
# 6300                          Adventure/3D/First-Person        2023-03-30
# 6301                                  Adventure/General        2023-03-30
# 6302                            Role-Playing/Action RPG        2023-03-30
# 6303                         Strategy/Real-Time/Command        2023-04-04
#
#       Critic Score User Score    Year
# 0               78        8.6  2005.0
# 1               74        7.0  2017.0
# 2               84        7.7  2017.0
# 3               84        7.9  2017.0
# 4               65        6.3  2017.0
# ...            ...        ...     ...
# 6299            81        tbd  2023.0
# 6300            74        tbd  2023.0
# 6301            81        tbd  2023.0
# 6302            59        tbd  2023.0
# 6303            79        NaN  2023.0
#
# [6304 rows x 8 columns]
